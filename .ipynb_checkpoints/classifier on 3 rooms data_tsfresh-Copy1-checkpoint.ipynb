# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn import neighbors
from math import sqrt

from sklearn import metrics
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\Anuj\SideChannelAttack\Extracted_features_from_magnetometer_readings_Cleaned.csv")

# %%
data
# Out:
#     Unnamed: 0  Magnitude__abs_energy  Magnitude__absolute_sum_of_changes  \
# 0            1           38196.839416                           15.730598
# 1            1           38350.589049                           15.159211
# 2            1           37748.777465                           16.175135
# 3            1           37025.388548                           14.407682
# 4            1           35471.342041                           15.680723
# ..         ...                    ...                                 ...
# 72           3           33663.784727                           13.843845
# 73           3           32686.258545                           17.908074
# 74           3           30713.180206                           14.817158
# 75           3           33171.398009                           16.372867
# 76           3           32201.940003                           15.290058
#
#     Magnitude__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                           -0.041109
# 1                                           -0.034701
# 2                                           -0.018500
# 3                                           -0.105366
# 4                                           -0.106679
# ..                                                ...
# 72                                          -0.054119
# 73                                          -0.019959
# 74                                          -0.022046
# 75                                          -0.020215
# 76                                          -0.108224
#
#     Magnitude__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                           -0.049222
# 1                                            0.023161
# 2                                           -0.061378
# 3                                           -0.099327
# 4                                           -0.148544
# ..                                                ...
# 72                                          -0.068446
# 73                                           0.010272
# 74                                           0.008090
# 75                                          -0.023867
# 76                                          -0.199060
#
#     Magnitude__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# 0                                            0.062105
# 1                                            0.108069
# 2                                            0.075548
# 3                                            0.131342
# 4                                            0.336794
# ..                                                ...
# 72                                           0.100715
# 73                                           0.042416
# 74                                           0.092820
# 75                                           0.033167
# 76                                           0.188900
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# 0                                           25.273309
# 1                                           26.208657
# 2                                           25.615439
# 3                                           25.637383
# 4                                           25.476993
# ..                                                ...
# 72                                          24.389290
# 73                                          23.943848
# 74                                          22.845247
# 75                                          23.732554
# 76                                          24.347595
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# 0                                           24.878358
# 1                                           25.681117
# 2                                           25.073784
# 3                                           25.158538
# 4                                           25.213351
# ..                                                ...
# 72                                          23.992663
# 73                                          23.326531
# 74                                          22.131015
# 75                                          23.334745
# 76                                          23.741321
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# 0                                           24.414126
# 1                                           25.049185
# 2                                           24.754291
# 3                                           24.466985
# 4                                           24.818035
# ..                                                ...
# 72                                          23.430376
# 73                                          22.597841
# 74                                          21.487709
# 75                                          22.804081
# 76                                          23.206915
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# 0                                            0.055069
# 1                                            0.123030
# 2                                            0.077592
# 3                                            0.120080
# 4                                           -0.033318
# ..                                                ...
# 72                                           0.067722
# 73                                           0.203778
# 74                                           0.204369
# 75                                           0.072618
# 76                                           0.160440
#
#     ...  Z__symmetry_looking__r_0.9500000000000001  \
# 0   ...                                        1.0
# 1   ...                                        1.0
# 2   ...                                        1.0
# 3   ...                                        1.0
# 4   ...                                        1.0
# ..  ...                                        ...
# 72  ...                                        1.0
# 73  ...                                        1.0
# 74  ...                                        1.0
# 75  ...                                        1.0
# 76  ...                                        1.0
#
#     Z__time_reversal_asymmetry_statistic__lag_1  \
# 0                                      3.908693
# 1                                      9.952164
# 2                                     17.494609
# 3                                      1.831162
# 4                                      8.436691
# ..                                          ...
# 72                                    14.071379
# 73                                   -18.243557
# 74                                   -11.814355
# 75                                    25.580603
# 76                                     5.348000
#
#     Z__time_reversal_asymmetry_statistic__lag_2  \
# 0                                      2.319009
# 1                                     44.273556
# 2                                     35.507800
# 3                                     -8.068637
# 4                                     37.120551
# ..                                          ...
# 72                                    27.909304
# 73                                   -28.525421
# 74                                   -24.754849
# 75                                    48.576762
# 76                                     7.047625
#
#     Z__time_reversal_asymmetry_statistic__lag_3  Z__value_count__value_-1  \
# 0                                     -0.012910                       0.0
# 1                                     67.561471                       0.0
# 2                                     47.832088                       0.0
# 3                                    -11.245012                       0.0
# 4                                     72.154189                       0.0
# ..                                          ...                       ...
# 72                                    44.509738                       0.0
# 73                                   -24.200967                       0.0
# 74                                   -38.964664                       0.0
# 75                                    74.435868                       0.0
# 76                                     1.847960                       0.0
#
#     Z__value_count__value_0  Z__value_count__value_1  Z__variance  \
# 0                       0.0                      0.0     0.255944
# 1                       0.0                      0.0     0.304611
# 2                       0.0                      0.0     0.191939
# 3                       0.0                      0.0     0.174224
# 4                       0.0                      0.0     0.620451
# ..                      ...                      ...          ...
# 72                      0.0                      0.0     0.237459
# 73                      0.0                      0.0     0.162419
# 74                      0.0                      0.0     0.424416
# 75                      0.0                      0.0     0.346331
# 76                      0.0                      0.0     0.259076
#
#     Z__variance_larger_than_standard_deviation  Z__variation_coefficient
# 0                                          0.0                 -0.030803
# 1                                          0.0                 -0.033825
# 2                                          0.0                 -0.028172
# 3                                          0.0                 -0.027819
# 4                                          0.0                 -0.055758
# ..                                         ...                       ...
# 72                                         0.0                 -0.030746
# 73                                         0.0                 -0.025441
# 74                                         0.0                 -0.041633
# 75                                         0.0                 -0.037563
# 76                                         0.0                 -0.035050
#
# [77 rows x 1944 columns]

# %%
X = data.drop("Unnamed: 0", 1)
y = data["Unnamed: 0"]

# %%
X
# Out:
#     Magnitude__abs_energy  Magnitude__absolute_sum_of_changes  \
# 0            38196.839416                           15.730598
# 1            38350.589049                           15.159211
# 2            37748.777465                           16.175135
# 3            37025.388548                           14.407682
# 4            35471.342041                           15.680723
# ..                    ...                                 ...
# 72           33663.784727                           13.843845
# 73           32686.258545                           17.908074
# 74           30713.180206                           14.817158
# 75           33171.398009                           16.372867
# 76           32201.940003                           15.290058
#
#     Magnitude__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                           -0.041109
# 1                                           -0.034701
# 2                                           -0.018500
# 3                                           -0.105366
# 4                                           -0.106679
# ..                                                ...
# 72                                          -0.054119
# 73                                          -0.019959
# 74                                          -0.022046
# 75                                          -0.020215
# 76                                          -0.108224
#
#     Magnitude__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                           -0.049222
# 1                                            0.023161
# 2                                           -0.061378
# 3                                           -0.099327
# 4                                           -0.148544
# ..                                                ...
# 72                                          -0.068446
# 73                                           0.010272
# 74                                           0.008090
# 75                                          -0.023867
# 76                                          -0.199060
#
#     Magnitude__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# 0                                            0.062105
# 1                                            0.108069
# 2                                            0.075548
# 3                                            0.131342
# 4                                            0.336794
# ..                                                ...
# 72                                           0.100715
# 73                                           0.042416
# 74                                           0.092820
# 75                                           0.033167
# 76                                           0.188900
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# 0                                           25.273309
# 1                                           26.208657
# 2                                           25.615439
# 3                                           25.637383
# 4                                           25.476993
# ..                                                ...
# 72                                          24.389290
# 73                                          23.943848
# 74                                          22.845247
# 75                                          23.732554
# 76                                          24.347595
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# 0                                           24.878358
# 1                                           25.681117
# 2                                           25.073784
# 3                                           25.158538
# 4                                           25.213351
# ..                                                ...
# 72                                          23.992663
# 73                                          23.326531
# 74                                          22.131015
# 75                                          23.334745
# 76                                          23.741321
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# 0                                           24.414126
# 1                                           25.049185
# 2                                           24.754291
# 3                                           24.466985
# 4                                           24.818035
# ..                                                ...
# 72                                          23.430376
# 73                                          22.597841
# 74                                          21.487709
# 75                                          22.804081
# 76                                          23.206915
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# 0                                            0.055069
# 1                                            0.123030
# 2                                            0.077592
# 3                                            0.120080
# 4                                           -0.033318
# ..                                                ...
# 72                                           0.067722
# 73                                           0.203778
# 74                                           0.204369
# 75                                           0.072618
# 76                                           0.160440
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# 0                                           26.177241
# 1                                           26.321862
# 2                                           26.240861
# 3                                           26.018839
# 4                                           25.502918
# ..                                                ...
# 72                                          24.544083
# 73                                          24.271340
# 74                                          24.033752
# 75                                          24.000750
# 76                                          24.485955
#
#     ...  Z__symmetry_looking__r_0.9500000000000001  \
# 0   ...                                        1.0
# 1   ...                                        1.0
# 2   ...                                        1.0
# 3   ...                                        1.0
# 4   ...                                        1.0
# ..  ...                                        ...
# 72  ...                                        1.0
# 73  ...                                        1.0
# 74  ...                                        1.0
# 75  ...                                        1.0
# 76  ...                                        1.0
#
#     Z__time_reversal_asymmetry_statistic__lag_1  \
# 0                                      3.908693
# 1                                      9.952164
# 2                                     17.494609
# 3                                      1.831162
# 4                                      8.436691
# ..                                          ...
# 72                                    14.071379
# 73                                   -18.243557
# 74                                   -11.814355
# 75                                    25.580603
# 76                                     5.348000
#
#     Z__time_reversal_asymmetry_statistic__lag_2  \
# 0                                      2.319009
# 1                                     44.273556
# 2                                     35.507800
# 3                                     -8.068637
# 4                                     37.120551
# ..                                          ...
# 72                                    27.909304
# 73                                   -28.525421
# 74                                   -24.754849
# 75                                    48.576762
# 76                                     7.047625
#
#     Z__time_reversal_asymmetry_statistic__lag_3  Z__value_count__value_-1  \
# 0                                     -0.012910                       0.0
# 1                                     67.561471                       0.0
# 2                                     47.832088                       0.0
# 3                                    -11.245012                       0.0
# 4                                     72.154189                       0.0
# ..                                          ...                       ...
# 72                                    44.509738                       0.0
# 73                                   -24.200967                       0.0
# 74                                   -38.964664                       0.0
# 75                                    74.435868                       0.0
# 76                                     1.847960                       0.0
#
#     Z__value_count__value_0  Z__value_count__value_1  Z__variance  \
# 0                       0.0                      0.0     0.255944
# 1                       0.0                      0.0     0.304611
# 2                       0.0                      0.0     0.191939
# 3                       0.0                      0.0     0.174224
# 4                       0.0                      0.0     0.620451
# ..                      ...                      ...          ...
# 72                      0.0                      0.0     0.237459
# 73                      0.0                      0.0     0.162419
# 74                      0.0                      0.0     0.424416
# 75                      0.0                      0.0     0.346331
# 76                      0.0                      0.0     0.259076
#
#     Z__variance_larger_than_standard_deviation  Z__variation_coefficient
# 0                                          0.0                 -0.030803
# 1                                          0.0                 -0.033825
# 2                                          0.0                 -0.028172
# 3                                          0.0                 -0.027819
# 4                                          0.0                 -0.055758
# ..                                         ...                       ...
# 72                                         0.0                 -0.030746
# 73                                         0.0                 -0.025441
# 74                                         0.0                 -0.041633
# 75                                         0.0                 -0.037563
# 76                                         0.0                 -0.035050
#
# [77 rows x 1943 columns]

# %%
y
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 72    3
# 73    3
# 74    3
# 75    3
# 76    3
# Name: Unnamed: 0, Length: 77, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 4)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (53, 1943) (24, 1943) (53,) (24,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ## pytcart Random Forest Model

# %%
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.utilities.dataframe_functions import impute


relevant_features = set()

for label in y.unique():
    y_train_binary = y_train == label
    X_train_filtered = select_features(X_train, y_train_binary)
    print("Number of relevant features for class {}: {}/{}".format(label, X_train_filtered.shape[1], X_train.shape[1]))
    relevant_features = relevant_features.union(set(X_train_filtered.columns))
# Out:
# Number of relevant features for class 1: 136/1943
# Number of relevant features for class 2: 172/1943
# Number of relevant features for class 3: 198/1943

# %%
len(relevant_features)
# Out:
# 303

# %%
relevant_features
# Out:
# {'Magnitude__abs_energy',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'Magnitude__c3__lag_1',
#  'Magnitude__c3__lag_2',
#  'Magnitude__c3__lag_3',
#  'Magnitude__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_13__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_5__w_2__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'Magnitude__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#  'Magnitude__fft_aggregated__aggtype_"centroid"',
#  'Magnitude__fft_aggregated__aggtype_"kurtosis"',
#  'Magnitude__fft_aggregated__aggtype_"skew"',
#  'Magnitude__fft_aggregated__aggtype_"variance"',
#  'Magnitude__fft_coefficient__attr_"abs"__coeff_0',
#  'Magnitude__fft_coefficient__attr_"real"__coeff_0',
#  'Magnitude__linear_trend__attr_"intercept"',
#  'Magnitude__max_langevin_fixed_point__m_3__r_30',
#  'Magnitude__maximum',
#  'Magnitude__mean',
#  'Magnitude__median',
#  'Magnitude__minimum',
#  'Magnitude__quantile__q_0.1',
#  'Magnitude__quantile__q_0.2',
#  'Magnitude__quantile__q_0.3',
#  'Magnitude__quantile__q_0.4',
#  'Magnitude__quantile__q_0.6',
#  'Magnitude__quantile__q_0.7',
#  'Magnitude__quantile__q_0.8',
#  'Magnitude__quantile__q_0.9',
#  'Magnitude__sum_values',
#  'Magnitude__variation_coefficient',
#  'X__abs_energy',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'X__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'X__c3__lag_1',
#  'X__c3__lag_2',
#  'X__c3__lag_3',
#  'X__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'X__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#  'X__fft_coefficient__attr_"abs"__coeff_0',
#  'X__fft_coefficient__attr_"real"__coeff_0',
#  'X__linear_trend__attr_"intercept"',
#  'X__maximum',
#  'X__mean',
#  'X__median',
#  'X__quantile__q_0.1',
#  'X__quantile__q_0.2',
#  'X__quantile__q_0.3',
#  'X__quantile__q_0.4',
#  'X__quantile__q_0.6',
#  'X__quantile__q_0.7',
#  'X__quantile__q_0.8',
#  'X__quantile__q_0.9',
#  'X__sum_values',
#  'Y__abs_energy',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'Y__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'Y__c3__lag_1',
#  'Y__c3__lag_2',
#  'Y__c3__lag_3',
#  'Y__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'Y__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#  'Y__fft_coefficient__attr_"abs"__coeff_0',
#  'Y__fft_coefficient__attr_"real"__coeff_0',
#  'Y__linear_trend__attr_"intercept"',
#  'Y__maximum',
#  'Y__mean',
#  'Y__median',
#  'Y__minimum',
#  'Y__quantile__q_0.1',
#  'Y__quantile__q_0.2',
#  'Y__quantile__q_0.3',
#  'Y__quantile__q_0.4',
#  'Y__quantile__q_0.6',
#  'Y__quantile__q_0.7',
#  'Y__quantile__q_0.8',
#  'Y__quantile__q_0.9',
#  'Y__sum_values',
#  'Z__abs_energy',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'Z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'Z__c3__lag_1',
#  'Z__c3__lag_2',
#  'Z__c3__lag_3',
#  'Z__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_13__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_14__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_5__w_2__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'Z__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#  'Z__fft_aggregated__aggtype_"centroid"',
#  'Z__fft_aggregated__aggtype_"kurtosis"',
#  'Z__fft_aggregated__aggtype_"skew"',
#  'Z__fft_aggregated__aggtype_"variance"',
#  'Z__fft_coefficient__attr_"abs"__coeff_0',
#  'Z__fft_coefficient__attr_"real"__coeff_0',
#  'Z__linear_trend__attr_"intercept"',
#  'Z__maximum',
#  'Z__mean',
#  'Z__median',
#  'Z__minimum',
#  'Z__quantile__q_0.1',
#  'Z__quantile__q_0.2',
#  'Z__quantile__q_0.3',
#  'Z__quantile__q_0.4',
#  'Z__quantile__q_0.6',
#  'Z__quantile__q_0.7',
#  'Z__quantile__q_0.8',
#  'Z__quantile__q_0.9',
#  'Z__sum_of_reoccurring_data_points',
#  'Z__sum_of_reoccurring_values',
#  'Z__sum_values',
#  'Z__variation_coefficient'}

# %%
X_train_filtered = X_train[list(relevant_features)]
X_test_filtered = X_test[list(relevant_features)]

# %%
X_train_filtered.head()
# Out:
#     Y__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)  Z__minimum  \
# 11                                         -39.407495          -14.940000
# 39                                         -34.653592          -21.840000
# 22                                         -79.122939          -10.679999
# 18                                         -35.832361          -13.980000
# 64                                         -35.344769          -16.740000
#
#     Z__linear_trend__attr_"intercept"  \
# 11                         -14.175442
# 39                         -20.924262
# 22                         -10.017692
# 18                         -13.414360
# 64                         -15.587377
#
#     Z__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# 11                                         -12.960000
# 39                                         -20.160000
# 22                                         -16.250959
# 18                                         -12.179999
# 64                                         -14.580000
#
#     Magnitude__fft_aggregated__aggtype_"variance"  \
# 11                                       9.096294
# 39                                       6.638158
# 22                                       0.446052
# 18                                       7.140376
# 64                                       7.444281
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"  \
# 11                                          22.961459
# 39                                          28.699785
# 22                                          17.858877
# 18                                          20.717058
# 64                                          22.112911
#
#     Y__abs_energy  \
# 11   75319.270086
# 39   61085.892742
# 22   13144.057067
# 18   67154.279591
# 64   59985.851360
#
#     Magnitude__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)  \
# 11                                          36.071754
# 39                                          45.821243
# 22                                          45.069989
# 18                                          32.359799
# 64                                          34.571945
#
#     Z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"  \
# 11                                         -14.177077
# 39                                         -20.932154
# 22                                          -9.893999
# 18                                         -13.401846
# 64                                         -15.580000
#
#     Z__c3__lag_3  ...  \
# 11  -2803.184802  ...
# 39  -9415.078130  ...
# 22   -983.745079  ...
# 18  -2260.579535  ...
# 64  -3756.102708  ...
#
#     Y__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)  \
# 11                                         -74.283631
# 39                                         -65.973421
# 22                                         -43.192189
# 18                                         -68.897461
# 64                                         -66.471849
#
#     Magnitude__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)  \
# 11                                          24.830702
# 39                                          31.273520
# 22                                          42.237789
# 18                                          22.550112
# 64                                          23.364170
#
#     Z__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)  \
# 11                                          -6.982694
# 39                                         -10.070372
# 22                                         -18.300788
# 18                                          -5.656716
# 64                                          -8.828614
#
#     Y__quantile__q_0.9  \
# 11          -34.854000
# 39          -31.320000
# 22          -32.880000
# 18          -33.059998
# 64          -31.199999
#
#     Z__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)  \
# 11                                         -23.167844
# 39                                         -34.632115
# 22                                         -23.620446
# 18                                         -21.358394
# 64                                         -26.198842
#
#     Magnitude__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)  \
# 11                                          25.900655
# 39                                          31.909656
# 22                                          40.456784
# 18                                          24.061575
# 64                                          23.777556
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# 11                                          22.476832
# 39                                          28.210207
# 22                                          16.535416
# 18                                          20.015124
# 64                                          21.499710
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"  \
# 11                                          23.258863
# 39                                          28.928747
# 22                                          18.676975
# 18                                          21.029808
# 64                                          22.520697
#
#     Magnitude__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# 11                                          13.012730
# 39                                          15.599319
# 22                                          11.131267
# 18                                          10.528910
# 64                                          12.278127
#
#     Z__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)
# 11                                          -7.950156
# 39                                         -12.012638
# 22                                          -6.049906
# 18                                          -6.726092
# 64                                          -8.741381
#
# [5 rows x 303 columns]

# %%
X_test_filtered.head()
# Out:
#     Y__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)  Z__minimum  \
# 49                                         -76.486233          -21.960000
# 66                                         -33.992100          -16.260000
# 60                                         -34.132819          -15.719999
# 48                                         -37.607589          -22.439999
# 14                                         -38.201062          -14.820000
#
#     Z__linear_trend__attr_"intercept"  \
# 49                         -21.833454
# 66                         -14.603934
# 60                         -15.234295
# 48                         -20.949836
# 14                         -14.110393
#
#     Z__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# 49                                         -16.250959
# 66                                         -13.559999
# 60                                         -12.000000
# 48                                         -19.800000
# 14                                         -13.259999
#
#     Magnitude__fft_aggregated__aggtype_"variance"  \
# 49                                       0.113248
# 66                                       7.862969
# 60                                      10.124950
# 48                                       6.901911
# 14                                       8.379853
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"  \
# 49                                          27.326634
# 66                                          21.605458
# 60                                          21.402074
# 48                                          25.783571
# 14                                          23.498090
#
#     Y__abs_energy  \
# 49   11773.144664
# 66   58911.640558
# 60   60726.414815
# 48   69831.735741
# 14   74824.907646
#
#     Magnitude__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)  \
# 49                                          54.530659
# 66                                          33.704080
# 60                                          35.248530
# 48                                          41.347296
# 14                                          35.991239
#
#     Z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"  \
# 49                                         -21.780000
# 66                                         -14.638307
# 60                                         -15.136154
# 48                                         -20.963077
# 14                                         -14.090615
#
#     Z__c3__lag_3  ...  \
# 49 -10216.925887  ...
# 66  -3500.528789  ...
# 60  -2646.753231  ...
# 48  -9586.486262  ...
# 14  -2644.596685  ...
#
#     Y__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)  \
# 49                                         -39.302125
# 66                                         -64.272285
# 60                                         -64.685530
# 48                                         -70.244397
# 14                                         -72.654247
#
#     Magnitude__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)  \
# 49                                          60.792720
# 66                                          22.973341
# 60                                          24.838978
# 48                                          29.123673
# 14                                          24.585619
#
#     Z__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)  \
# 49                                          -9.218447
# 66                                          -8.384474
# 60                                          -8.921598
# 48                                         -12.473070
# 14                                          -7.177733
#
#     Y__quantile__q_0.9  \
# 49             -33.762
# 66             -30.720
# 60             -30.834
# 48             -33.408
# 14             -34.620
#
#     Z__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)  \
# 49                                         -37.855972
# 66                                         -24.359796
# 60                                         -27.173498
# 48                                         -36.470620
# 14                                         -23.454513
#
#     Magnitude__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)  \
# 49                                          63.132814
# 66                                          23.538111
# 60                                          24.492511
# 48                                          29.265270
# 14                                          26.290224
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# 49                                          24.316838
# 66                                          20.842538
# 60                                          20.938104
# 48                                          24.598224
# 14                                          22.951925
#
#     Magnitude__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"  \
# 49                                          27.737548
# 66                                          22.193067
# 60                                          22.066474
# 48                                          26.505386
# 14                                          23.780690
#
#     Magnitude__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# 49                                          18.834521
# 66                                          12.032528
# 60                                          12.140254
# 48                                          16.215853
# 14                                          12.424899
#
#     Z__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)
# 49                                         -14.844165
# 66                                          -7.761973
# 60                                          -8.433201
# 48                                         -13.269180
# 14                                          -7.470900
#
# [5 rows x 303 columns]

# %%
classifier = RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
                       criterion='entropy', max_depth=60, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=5,
                       min_weight_fraction_leaf=0.0, n_estimators=40,
                       n_jobs=None, oob_score=False, random_state=5635,
                       verbose=0, warm_start=False)

# %%
classifier.fit(X_train_filtered, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=60,
#                        min_samples_leaf=4, min_samples_split=5, n_estimators=40,
#                        random_state=5635)

# %%
y_pred = classifier.predict(X_test_filtered)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[9 0 0]
#  [0 9 0]
#  [0 0 6]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00         6
#
#     accuracy                           1.00        24
#    macro avg       1.00      1.00      1.00        24
# weighted avg       1.00      1.00      1.00        24

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
classifier  = tree.DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
                       max_depth=150, max_features=251, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, presort='deprecated',
                       random_state=6624, splitter='best')

# %%
classifier.fit(X_train_filtered, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=150, max_features=251,
#                        min_samples_leaf=4, random_state=6624)

# %%
y_pred = classifier.predict(X_test_filtered)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9583333333333334

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[9 0 0]
#  [1 8 0]
#  [0 0 6]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.90      1.00      0.95         9
#            2       1.00      0.89      0.94         9
#            3       1.00      1.00      1.00         6
#
#     accuracy                           0.96        24
#    macro avg       0.97      0.96      0.96        24
# weighted avg       0.96      0.96      0.96        24

# %% [markdown]
# ## Sklearn Random Forest

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train_filtered,y_train)

y_pred=clf.predict(X_test_filtered)

error = sqrt(metrics.mean_squared_error( y_test, y_pred)) 
print('RMSE value of the KNN Model is:', error)

print(accuracy_score(y_test,y_pred))

print(confusion_matrix(y_test,y_pred))

print(classification_report(y_test,y_pred))
# Out:
# RMSE value of the KNN Model is: 0.0
# 1.0
# [[9 0 0]
#  [0 9 0]
#  [0 0 6]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00         6
#
#     accuracy                           1.00        24
#    macro avg       1.00      1.00      1.00        24
# weighted avg       1.00      1.00      1.00        24

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 9)

knn.fit(X_train_filtered, y_train)

y_pred = knn.predict(X_test_filtered)

print("Test Score: ", knn.score(X_test_filtered, y_test))
# Out:
# Test Score:  0.875

# %% [markdown]
# ## SVC

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

cv_grid_svc = GridSearchCV(SVC(), param_grid = {
    'degree':[3,4],
    'shrinking':[True,False],
    'probability':[True,False]
}, cv=10)

cv_grid_svc.fit(X_train_filtered, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'degree': [3, 4], 'probability': [True, False],
#                          'shrinking': [True, False]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
bestclassifier_svc=cv_grid_svc.best_estimator_

y_predict_svc = bestclassifier_svc.predict(X_test_filtered)
accuracy = metrics.accuracy_score(y_test,y_predict_svc)
print(cv_grid_svc.best_params_)
print('Accuracy of the best classifier after CV is %.3f%%' % (accuracy*100))
# Out:
# {'degree': 3, 'probability': True, 'shrinking': True}
# Accuracy of the best classifier after CV is 87.500%

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

cv_grid_rf = GridSearchCV(estimator = RandomForestClassifier(), param_grid = {
    'n_estimators': range(10, 100, 10),
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}, cv=10)

cv_grid_rf.fit(X_train_filtered, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': range(10, 100, 10)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
bestclassifier_rf=cv_grid_rf.best_estimator_

y_predict_rf = bestclassifier_rf.predict(X_test_filtered)
accuracy = metrics.accuracy_score(y_test,y_predict_rf)
print(cv_grid_rf.best_params_)
print('Accuracy of the best classifier after CV is %.3f%%' % (accuracy*100))
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'n_estimators': 30}
# Accuracy of the best classifier after CV is 95.833%

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

cv_grid_lr = GridSearchCV(estimator = LogisticRegression(), param_grid = {
    'C': np.logspace(0, 4, 10),
    'penalty': ['l1', 'l2'],
}, cv=10)

cv_grid_lr.fit(X_train_filtered, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': array([1.00000000e+00, 2.78255940e+00, 7.74263683e+00, 2.15443469e+01,
#        5.99484250e+01, 1.66810054e+02, 4.64158883e+02, 1.29154967e+03,
#        3.59381366e+03, 1.00000000e+04]),
#                          'penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
bestclassifier_lr=cv_grid_lr.best_estimator_

y_predict_lr = bestclassifier_lr.predict(X_test_filtered)
accuracy = metrics.accuracy_score(y_test,y_predict_lr)
print(cv_grid_lr.best_params_)
print("NUMBER OF ERRORS: " + str(sum(y_predict_lr != y_test)))
print("ERROR RATE: " + str(1 - sum(y_predict_lr == y_test) / float(len(y_predict_lr))) + "%")
print('Accuracy of the best classifier after CV is %.3f%%' % (accuracy*100))
# Out:
# {'C': 1.0, 'penalty': 'l2'}
# NUMBER OF ERRORS: 1
# ERROR RATE: 0.04166666666666663%
# Accuracy of the best classifier after CV is 95.833%

# %% [markdown]
# ## KNN

# %%
cv_grid_knn = GridSearchCV(estimator = KNeighborsClassifier(), param_grid = {
    'n_neighbors':[4,5,6,7],
    'leaf_size':[1,3,5],
    'algorithm':['auto', 'kd_tree']
}, cv=10)

cv_grid_knn.fit(X_train_filtered, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'algorithm': ['auto', 'kd_tree'],
#                          'leaf_size': [1, 3, 5], 'n_neighbors': [4, 5, 6, 7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
bestclassifier_knn=cv_grid_knn.best_estimator_

y_predict_knn = bestclassifier_knn.predict(X_test_filtered)
accuracy = metrics.accuracy_score(y_test,y_predict_knn)
print(cv_grid_knn.best_params_)
print("NUMBER OF ERRORS: " + str(sum(y_predict_knn != y_test)))
print("ERROR RATE: " + str(1 - sum(y_predict_knn == y_test) / float(len(y_predict_knn))) + "%")
print('Accuracy of the best classifier after CV is %.3f%%' % (accuracy*100))
# Out:
# {'algorithm': 'auto', 'leaf_size': 1, 'n_neighbors': 4}
# NUMBER OF ERRORS: 1
# ERROR RATE: 0.04166666666666663%
# Accuracy of the best classifier after CV is 95.833%

# %% [markdown]
# ## XGBOOST

# %%
from xgboost import XGBClassifier

cv_grid_xb = GridSearchCV(estimator = XGBClassifier(), param_grid = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(10, 100, 10),
    'learning_rate': [0.1, 0.01, 0.05]
}, cv=10)

cv_grid_xb.fit(X_train_filtered, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_esti...
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10),
#                          'n_estimators': range(10, 100, 10)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
bestclassifier_xb=cv_grid_xb.best_estimator_

y_predict_xb = bestclassifier_xb.predict(X_test_filtered)
accuracy = metrics.accuracy_score(y_test,y_predict_xb)
print(cv_grid_xb.best_params_)
print("NUMBER OF ERRORS: " + str(sum(y_predict_xb != y_test)))
print("ERROR RATE: " + str(1 - sum(y_predict_xb == y_test) / float(len(y_predict_xb))) + "%")
print('Accuracy of the best classifier after CV is %.3f%%' % (accuracy*100))
# Out:
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 10}
# NUMBER OF ERRORS: 0
# ERROR RATE: 0.0%
# Accuracy of the best classifier after CV is 100.000%
